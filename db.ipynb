# %%
import pyodbc

server = 'myguru.database.windows.net'
database = 'myguru'
username = 'soumyadeep'
password = 'Ahold@123'

connection_string = (
    'DRIVER={ODBC Driver 18 for SQL Server};'
    f'SERVER={server};'
    f'DATABASE={database};'
    f'UID={username};'
    f'PWD={password};'
    'Encrypt=yes;'
    'TrustServerCertificate=no;'
    'Connection Timeout=30;'
)

conn = pyodbc.connect(connection_string)
cursor = conn.cursor()

print("✅ Connected to Azure SQL Database")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 19
#      15     'TrustServerCertificate=no;'
#      16     'Connection Timeout=30;'
#      17 )
#      18
# ---> 19 conn = pyodbc.connect(connection_string)
#      20 cursor = conn.cursor()
#      21
#      22 print("✅ Connected to Azure SQL Database")
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Cannot open server 'myguru' requested by the login. Client is not allowed to access the server. (40914) (SQLDriverConnect); [42000] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Cannot open server 'myguru' requested by the login. Client is not allowed to access the server. (40914)")
